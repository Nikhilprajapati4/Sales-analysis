# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import os

# %%
from sqlalchemy import create_engine

#connect to server
engine = create_engine(
    "postgresql://postgres:12345@localhost:5432/Olist_DB")

# %% [markdown]
# ## Load to SQL

# %%
import pandas as pd
import os
from sqlalchemy import create_engine

#connect to server
engine = create_engine(
    "postgresql://postgres:12345@localhost:5432/Olist_DB")


#function
def load_to_postgres(df , table , engine) :
    """ Here we load data from dir to SQL"""
    df.to_sql(table, con= engine , if_exists="replace" , index = False)

#find file by os
for file in os.listdir(r"d:\Projects\sales analysis\Dataset") :
    df = pd.read_csv(f"d:\Projects\sales analysis\Dataset\{file}")
    # load_to_postgres(df,file[:-4],engine)
print(f"Data load successfully !!!")

# script
# from ingestion import Load_data
# Load_data()

# %% [markdown]
# ## Access data from SQL

# %%
# name of tables
from sqlalchemy import inspect
inspector = inspect(engine)
tables = inspector.get_table_names()
print(tables)
# Out:
# ['olist_geolocation_dataset', 'olist_order_items_dataset', 'olist_customers_dataset', 'olist_orders_dataset', 'olist_order_payments_dataset', 'olist_order_reviews_dataset', 'olist_products_dataset', 'olist_sellers_dataset', 'product_category_name_translation']

# %%
for table in tables :
    print(table)
    print(pd.read_sql(F"SELECT COUNT(*) FROM {table}",engine)['count'].values[0])
    df = pd.read_sql(F"SELECT * FROM {table}",engine)
    print(df.columns)
    display(df.head(3))
# Out:
# olist_geolocation_dataset
# 1000163
# Index(['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng',
#        'geolocation_city', 'geolocation_state'],
#       dtype='object')
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# olist_order_items_dataset
# 112650
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# ...

# %% [markdown]
# ### Business Question
#     What is the total revenue?
#     How are monthly sales changing?
#     Which product categories generate the most revenue?
#     Which states and cities contribute the highest sales?
#     What is the Average Order Value (AOV)?
#     Which months have peak sales?
#     Which products sell the most?

# %%
quary = """SELECT * from olist_orders_dataset od join olist_order_payments_dataset op on od.order_id = op.order_id 
                                   WHERE od.order_status = 'delivered' ; """
revenue = pd.read_sql(quary, engine)
revenue["payment_value"].sum()
# Out:
# np.float64(15422461.77)

# %%
quary = """SELECT * from olist_orders_dataset od join olist_order_payments_dataset op on od.order_id = op.order_id 
                                   WHERE od.order_status = 'delivered' ; """
revenue = pd.read_sql(quary, engine)
revenue["payment_value"].sum()
# Out:
# np.float64(15422461.77)
